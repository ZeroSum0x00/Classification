# %%
# %cd "/content/drive/MyDrive/Image Classification/CLS - tensorflow 2"
# Out:
# /content/drive/MyDrive/Image Classification/CLS - tensorflow 2

# %%
import tensorflow as tf
from tensorflow.keras.losses import CategoricalCrossentropy, BinaryCrossentropy, SparseCategoricalCrossentropy
from utils.someones import *

# %%
loss_data = load_pickle('/content/drive/MyDrive/Resources/PyTorch examples/debug/loss_value.pickle')

# %%
images = loss_data['images']
labels = loss_data['labels']
preds = loss_data['preds']
loss = loss_data['loss']

# %%
preds.shape
# Out:
# (4, 1000)

# %%
losses = SparseCategoricalCrossentropy(from_logits=True)
r = losses(labels, preds)

# %%
r
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=9.33342>

# %%
losses = CategoricalCrossentropy(from_logits=True)
r = losses(tf.one_hot(labels, 1000), preds)

# %%
r
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=9.33342>
