# %%
# %cd "/content/drive/MyDrive/Image Classification/CLS - tensorflow 2"
# Out:
# /content/drive/MyDrive/Image Classification/CLS - tensorflow 2

# %%
from utils.config_processing import load_config
from augmenter import *

# %%
engine_file_config = "./configs/engine/train_supervised.yaml"
engine_config = load_config(engine_file_config)
# Out:
# 2024-11-01 06:04:25,784 - INFO - Load file ./configs/engine/train_supervised.yaml successfully
# INFO:YOLO:Load file ./configs/engine/train_supervised.yaml successfully

# %%
build_augmenter(engine_config['Dataset']['data_augmentation']['train'])
# Out:
# [<augmenter.geometric.resized_crop.RandomResizedCrop at 0x7826fdb2c640>,
#  <augmenter.meta_transform.RandomOrder at 0x7826fdb2c400>]
